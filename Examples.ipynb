# %%
import numpy as np
import pandas as pd
from physt import h1, h2, h3

# %matplotlib inline

# %%
# Generate data to use
NUM = 100000
ekin = np.random.normal(60, 5, NUM)
x = np.random.normal(0, 3, NUM) + (ekin - 60) ** 2 / 20
y = np.random.normal(0, 10, NUM) - x / 3

df = pd.DataFrame({
    "ekin": ekin,
    "x": x,
    "y": y
})
df.to_csv("protons.csv")

# %%
particles = pd.read_csv("protons.csv")
h = h1(particles["ekin"], title="Energy distribution of protons")
h
# Out:
# Histogram1D(bins=(10,), total=100000, dtype=int64)

# %%
h.bins
# Out:
# array([[ 38.83518235,  43.13083181],
#        [ 43.13083181,  47.42648128],
#        [ 47.42648128,  51.72213074],
#        [ 51.72213074,  56.01778021],
#        [ 56.01778021,  60.31342967],
#        [ 60.31342967,  64.60907914],
#        [ 64.60907914,  68.9047286 ],
#        [ 68.9047286 ,  73.20037807],
#        [ 73.20037807,  77.49602753],
#        [ 77.49602753,  81.791677  ]])

# %%
h.binning
# Out:
# NumpyBinning(array([ 38.83518235,  43.13083181,  47.42648128,  51.72213074,
#         56.01778021,  60.31342967,  64.60907914,  68.9047286 ,
#         73.20037807,  77.49602753,  81.791677  ]))

# %%
h.meta_data
# Out:
# {'axis_names': ['ekin'],
#  'name': None,
#  'title': 'Energy distribution of protons'}

# %%
h.plot(write_to="h1.png")

# %%
h2(particles["x"], particles["y"], 100).plot("image")

# %%
h2(df["ekin"], df["x"], 100).plot("image", cmap="rainbow")

# %%
h2(df["x"], df["y"], 100).plot("image", cmap="rainbow")
